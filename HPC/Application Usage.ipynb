# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [87.77, 2.87, 1.81, 1.64, 1.57, 1.13, 0.86, 0.44, 1.92]
labels = ['VASP', 'amber', 'G09', 'FAST', 'charmm', 'namd', 'QE', 'mfix', 'other']

# %%
plt.pie(data, labels=labels, labeldistance=1.1, radius=2.2, rotatelabels=True, startangle=22)
plt.savefig('Peregrine_2019_usagepie.svg', bbox_inches='tight')

# %%
data = [58.3, 7.2, 6.9, 5.9, 3, 2.7, 2.3, 2, 1.9, 1.8, 8.1]
labels = ['VASP', 'Converge', 'namd', 'WRF', 'PLEXOS', 'OpenFOAM', 'Amber', 'G09', 'Nalu', 'LAMMPS', 'other']

# %%
plt.pie(data, labels=labels, labeldistance=1.1, radius=2.2, rotatelabels=True, startangle=75)
plt.savefig('Peregrine_2018_usagepie.svg', bbox_inches='tight')

# %%
data = [29.3, 21.9, 21.1, 6.4, 5.2, 2.9, 2.9, 2.7, 2., 1.8, 1.4, 1.2, 1.2]
labels = ['other', 'WRF', 'VASP', 'Nalu', 'NAMD', 'MFix', 'G16', 'OpenFOAM', 'BGW', 'Amber', 'DL', 'QE', 'LAMMPS']

# %%
plt.pie(data, labels=labels, labeldistance=1.1, radius=2.2, rotatelabels=True, startangle=125)
plt.savefig('Eagle_2019_usagepie.svg', bbox_inches='tight')
